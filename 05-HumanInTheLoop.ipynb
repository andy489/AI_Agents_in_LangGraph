# %% [markdown]
# # Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
# pip install langchain-community

# %%
# pip install langchain-tavily

# %%
# pip install langgraph-checkpoint-sqlite

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilySearch
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()

# %%
from uuid import uuid4
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage

"""
In previous examples we've annotated the `messages` state key
with the default `operator.add` or `+` reducer, which always
appends new messages to the end of the existing messages array.

Now, to support replacing existing messages, we annotate the
`messages` key with a customer reducer function, which replaces
messages with the same `id`, and appends them otherwise.
"""
def reduce_messages(left: list[AnyMessage], right: list[AnyMessage]) -> list[AnyMessage]:
    # assign ids to messages that don't have them
    for message in right:
        if not message.id:
            message.id = str(uuid4())
    # merge the new messages with the existing messages
    merged = left.copy()
    for message in right:
        for i, existing in enumerate(merged):
            # replace any existing messages with the same id
            if existing.id == message.id:
                merged[i] = message
                break
        else:
            # append any new messages to the end
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], reduce_messages]

# %%
tool = TavilySearch(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"]
        )
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-3.5-turbo")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='733b58d9-daef-4fcc-a8f9-f1f598052ea2'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr3uR3Lt6xGpwABYHJoBwvHNeD9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-4768-74e2-b6cc-227fbc0849b7-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in San Francisco', 'search_depth': 'fast'}, 'id': 'call_5DyTa4mA1b5rDdpjwq1oZPHb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr3uR3Lt6xGpwABYHJoBwvHNeD9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-4768-74e2-b6cc-227fbc0849b7-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in San Francisco', 'search_depth': 'fast'}, 'id': 'call_5DyTa4mA1b5rDdpjwq1oZPHb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='733b58d9-daef-4fcc-a8f9-f1f598052ea2'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr3uR3Lt6xGpwABYHJoBwvHNeD9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-4768-74e2-b6cc-227fbc0849b7-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in San Francisco', 'search_depth': 'fast'}, 'id': 'call_5DyTa4mA1b5rDdpjwq1oZPHb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d6-baf1-6c8a-8001-49e3a829001e'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:07.569192+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d6-a668-6b1a-8000-8df3b56befb6'}}, tasks=(PregelTask(id='d02d7bda-67fd-ffd5-00c9-fe56461ac90b', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in San Francisco', 'search_depth': 'fast'}, 'id': 'call_5DyTa4mA1b5rDdpjwq1oZPHb', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in San Francisco\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.weatherandradar.in/weather/san-francisco/12350786\', \'title\': \'Current weather for San Francisco\', \'content\': "Weather San Francisco\\n\\nWeather News\\n\\nEditor\'s Pick\\n\\nDiscover the app\\n\\nWeather widget\\n\\nContact us\\n\\nCordoba · Argentina  Tue, 04/08 11:15 am\\n\\n# Weather San Francisco\\n\\n now \\n90 Min. Weather\\n\\nmostly cloudy\\n\\nSunrise and sunset 07:53 am  06:35 pm\\n\\n12:00 pm\\n\\n14\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n01:00 pm\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n02:00 pm\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n03:00 pm\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n04:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation [...] 40 %\\n\\nToday, in the morning it is partly cloudy. Towards the afternoon, cloud cover will thicken, but it will remain dry. The temperature is currently at 14 degrees and rises to 17 degrees during the day.\\n\\n## WeatherRadar\\n\\n## Forecast Map\\n\\nAfternoon\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nEvening\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nNight\\n\\n14\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nMorning\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nAfternoon\\n\\n17\\n\\n°\\n\\nProbability of precipitation [...] 11:00 am\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n12:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n01:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n02:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n03:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n04:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n05:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n06:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n07:00 pm\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n08:00 pm\\n\\n16\\n\\n°", \'score\': 0.8437023, \'raw_content\': None, \'id\': \'734784-00\'}, {\'url\': \'https://toxigon.com/san-francisco-weather-current-conditions\', \'title\': \'San Francisco Weather: Current Conditions Explained - Toxigon\', \'content\': "When it comes to temperature, San Francisco is generally cooler than you might expect for a California city. The average temperature in the summer is around 60-70 degrees Fahrenheit. It rarely gets super hot, which is great if you don\'t like the heat. But it also means you should pack a jacket, even in the summer. [...] San Francisco\'s weather is kinda like that friend who\'s always unpredictable but you love them anyway. It can go from foggy and chilly to sunny and warm in a heartbeat. I remember one summer day when I was walking around the Embarcadero, it was sunny, but the fog rolled in so fast, I ended up wearing my jacket. Anyway, understanding San Francisco\'s weather helps you plan your day better, whether you\'re a local or just visiting. [...] Winter in San Francisco is rainy and cool, with temperatures in the 50s. It doesn\'t usually snow, but the rain can be pretty steady. This is the time when the city gets most of its rainfall.\\n\\nIt\'s a good time to explore indoor attractions, like museums and theaters. But if you don\'t mind the rain, there are still plenty of outdoor activities to enjoy.\\n\\nJust remember to bring a raincoat and some warm clothes.\\n\\n## Weather Events to Watch Out For\\n\\n### Atmospheric Rivers: The Rain Makers", \'score\': 0.77364457, \'raw_content\': None, \'id\': \'6b6742-01\'}], \'response_time\': 0.0, \'request_id\': \'7250c465-ffb2-4424-bf3d-423618355229\'}', name='tavily_search', id='7a4f4059-ea4b-4a4f-8f3d-0fb506def558', tool_call_id='call_5DyTa4m ...
# {'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='733b58d9-daef-4fcc-a8f9-f1f598052ea2'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr3uR3Lt6xGpwABYHJoBwvHNeD9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-4768-74e2-b6cc-227fbc0849b7-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in San Francisco', 'search_depth': 'fast'}, 'id': 'call_5DyTa4mA1b5rDdpjwq1oZPHb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in San Francisco\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.weatherandradar.in/weather/san-francisco/12350786\', \'title\': \'Current weather for San Francisco\', \'content\': "Weather San Francisco\\n\\nWeather News\\n\\nEditor\'s Pick\\n\\nDiscover the app\\n\\nWeather widget\\n\\nContact us\\n\\nCordoba · Argentina  Tue, 04/08 11:15 am\\n\\n# Weather San Francisco\\n\\n now \\n90 Min. Weather\\n\\nmostly cloudy\\n\\nSunrise and sunset 07:53 am  06:35 pm\\n\\n12:00 pm\\n\\n14\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n01:00 pm\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n02:00 pm\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n03:00 pm\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n04:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation [...] 40 %\\n\\nToday, in the morning it is partly cloudy. Towards the afternoon, cloud cover will thicken, but it will remain dry. The temperature is currently at 14 degrees and rises to 17 degrees during the day.\\n\\n## WeatherRadar\\n\\n## Forecast Map\\n\\nAfternoon\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nEvening\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nNight\\n\\n14\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nMorning\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nAfternoon\\n\\n17\\n\\n°\\n\\nProbability of precipitation [...] 11:00 am\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n12:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n01:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n02:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n03:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n04:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n05:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n06:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n07:00 pm\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n08:00 pm\\n\\n16\\n\\n°", \'score\': 0.8437023, \'raw_content\': None, \'id\': \'734784-00\'}, {\'url\': \'https://toxigon.com/san-francisco-weather-current-conditions\', \'title\': \'San Francisco Weather: Current Conditions Explained - Toxigon\', \'content\': "When it comes to temperature, San Francisco is generally cooler than you might expect for a California city. The average temperature in the summer is around 60-70 degrees Fahrenheit. It rarely gets super hot, which is great if you don\'t like the heat. But it also means you should pack a jacket, even in the summer. [...]  ...
# {'messages': [AIMessage(content='The current weather in San Francisco is mostly cloudy with a temperature of 14 degrees Celsius, which is expected to rise to 17 degrees Celsius during the day. There is a 20% probability of precipitation.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 2398, 'total_tokens': 2441, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr6XhGxGuEnTKxBbXzMirLUHPRS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-5180-7f72-9c27-1e370ed8b710-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2398, 'output_tokens': 43, 'total_tokens': 2441, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='733b58d9-daef-4fcc-a8f9-f1f598052ea2'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr3uR3Lt6xGpwABYHJoBwvHNeD9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-4768-74e2-b6cc-227fbc0849b7-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in San Francisco', 'search_depth': 'fast'}, 'id': 'call_5DyTa4mA1b5rDdpjwq1oZPHb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in San Francisco\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.weatherandradar.in/weather/san-francisco/12350786\', \'title\': \'Current weather for San Francisco\', \'content\': "Weather San Francisco\\n\\nWeather News\\n\\nEditor\'s Pick\\n\\nDiscover the app\\n\\nWeather widget\\n\\nContact us\\n\\nCordoba · Argentina  Tue, 04/08 11:15 am\\n\\n# Weather San Francisco\\n\\n now \\n90 Min. Weather\\n\\nmostly cloudy\\n\\nSunrise and sunset 07:53 am  06:35 pm\\n\\n12:00 pm\\n\\n14\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n01:00 pm\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n02:00 pm\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n03:00 pm\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n04:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation [...] 40 %\\n\\nToday, in the morning it is partly cloudy. Towards the afternoon, cloud cover will thicken, but it will remain dry. The temperature is currently at 14 degrees and rises to 17 degrees during the day.\\n\\n## WeatherRadar\\n\\n## Forecast Map\\n\\nAfternoon\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nEvening\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nNight\\n\\n14\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nMorning\\n\\n15\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\nAfternoon\\n\\n17\\n\\n°\\n\\nProbability of precipitation [...] 11:00 am\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n12:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n01:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n02:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n03:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n04:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n20 %\\n\\n05:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n06:00 pm\\n\\n17\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n07:00 pm\\n\\n16\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n08:00 pm\\n\\n16\\n\\n°", \'score\': 0.8437023, \'raw_content\': None, \'id\': \'734784-00\'}, {\'url\': \'https://toxigon.com/san-francisco-weather-current-conditions\', \'title\': \'San Francisco Weather: Current Conditions Explained - Toxigon\', \'content\': "When it comes to temperature, San Francisco is generally cooler than you might expect for a California city. The average temperature in the summer is around 60-70 degrees Fahrenheit. It rarely gets super hot, which is great if you don\'t like the heat. But it also means you should pack a jacket, even  ...

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='d40f2c7e-fd94-4e58-b716-4fd87a85a260'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr7sElDKX29E6bliPoiqNDEEok8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-5631-7560-93e0-6dfa60d11f3c-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'search_depth': 'fast'}, 'id': 'call_0XfxTPbYgaAf5p8aOI8jhPeq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr7sElDKX29E6bliPoiqNDEEok8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-5631-7560-93e0-6dfa60d11f3c-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'search_depth': 'fast'}, 'id': 'call_0XfxTPbYgaAf5p8aOI8jhPeq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()
#
#  StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='d40f2c7e-fd94-4e58-b716-4fd87a85a260'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr7sElDKX29E6bliPoiqNDEEok8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-5631-7560-93e0-6dfa60d11f3c-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'search_depth': 'fast'}, 'id': 'call_0XfxTPbYgaAf5p8aOI8jhPeq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d6-d340-6516-8001-00209634b85d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:10.117938+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d6-ca81-6b00-8000-5521328f124a'}}, tasks=(PregelTask(id='0b399361-0781-4a1f-f8bc-cf6224751b08', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())
# proceed? y
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'search_depth': 'fast'}, 'id': 'call_0XfxTPbYgaAf5p8aOI8jhPeq', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.instagram.com/popular/current-weather-los-angeles-april-2026\', \'title\': \'Current Weather Los Angeles April 2026\', \'content\': \'Log In\\n\\nSign Up\\n\\n# Current Weather Los Angeles April 2026\\n\\nWatch reels about current weather los angeles april 2026 from people around the world.\\n\\nYour 21 March 2026 weather update for Los Angeles\\n\\n☀️ Los Angeles, United States — Sunny 21 March 2026 (27°C). Wind 9 km/h • UV 7 • Rain 0 mm. Save for later ✅\\n\\n#Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Sunny, #Sun, #Rain, #Cloudy, #Storm\\n\\n122 [...] 93\\n\\nYour 7 March 2026 weather update for Los Angeles ☀️ Forecast for 7 March 2026 in Los Angeles: Sunny. Temp 23°C, wind 7 km/h. Comment your district 🗺️ #Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Sunny, #Sun, #Rain, #Cloudy, #Storm\\n\\nWeather in Los Angeles 3 April 2026: Overcast (24°C)\\n\\n☁️ Quick forecast in Los Angeles: Overcast, 24°C. UV 7 • Rain 0 mm. Share in story if useful 📲 [...] 122\\n\\nYour 21 March 2026 weather update for Los Angeles ☀️ Los Angeles, United States — Sunny 21 March 2026 (27°C). Wind 9 km/h • UV 7 • Rain 0 mm. Save for later ✅ #Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Sunny, #Sun, #Rain, #Cloudy, #Storm\\n\\nYour 24 March 2026 weather update for Los Angeles\\n\\n☀️ Forecast for 24 March 2026 in Los Angeles: Sunny. Temp 25°C, wind 10 km/h. Comment your district 🗺️\', \'score\': 0.8585411, \'raw_content\': None, \'id\': \'050b03-00\'}, {\'url\': \'https://www.weatherandradar.in/weather/los-angeles/12139441\', \'title\': \'Current weather for Los Angeles\', \'content\': "Weather Los Angeles\\n\\nWeather News\\n\\nEditor\'s Pick\\n\\nDiscover the app\\n\\nWeather widget\\n\\nContact us\\n\\nCalifornia · United States  Wed, 29/07 06:11 am PDT\\n\\n# Weather Los Angeles\\n\\n now \\n90 Min. Weather\\n\\nmostly cloudy\\n\\nSunrise and sunset 06:02 am  07:56 pm\\n\\n07:00 am\\n\\n21\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n08:00 am\\n\\n21\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n09:00 am\\n\\n22\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\n10:00 am\\n\\n24\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\n11:00 am\\n\\n25\\n\\n° [...] 5 %\\n\\nToday, in the morning it is partly cloudy. Towards the afternoon, the sun comes out. The temperature is currently at 21 degrees and rises to 29 degrees during the day.\\n\\n## WeatherRadar\\n\\n## Forecast Map\\n\\nMorning\\n\\n22\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\nAfternoon\\n\\n29\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\nEvening\\n\\n22\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\nNight\\n\\n20\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\nMorning\\n\\n22\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\nAfternoon\\n\\n31\\n\\n° [...] We\\n\\n21\\n\\n29\\n\\nTh\\n\\n20\\n\\n31\\n\\nFr\\n\\n21\\n\\n32\\n\\nSa\\n\\n21\\n\\n34\\n\\nSu\\n\\n22\\n\\n33\\n\\nMo\\n\\n21\\n\\n31\\n\\nTu\\n\\n21\\n\\n30\\n\\nWe\\n\\n21\\n\\n29\\n\\nTh\\n\\n21\\n\\n29\\n\\nFr\\n\\n21\\n\\n28\\n\\nSa\\n\\n21\\n\\n28\\n\\nSu\\n\\n21\\n\\n27\\n\\nMo\\n\\n20\\n\\n27\\n\\nTu\\n\\n20\\n\\n28\\n\\nMax (°C)\\n\\nMin (°C)\\n\\nmoreless\\n\\n## TemperatureRadar\\n\\n## UV Index\\n\\ntoday\\n\\n10\\n\\nvery high\\n\\n [6-Day UV Forecast](/uv-index/los-angeles/12139441)\\n\\n## Current regional conditions\\n\\nBurbank (237m)\\n\\n20°\\n\\ncloudy\\n\\nWind E 7 kph\\n\\nEl Monte Airport (90m)\\n\\n31°\\n\\ndry\\n\\nWind SW 14 kph\\n\\nHwathorne Muni Airport (19m)\\n\\n22°\\n\\novercast\\n\\nWind 0 kph", \'score\': 0.85421735, \'raw_content\': None, \'id\': \'39e0b2-01\'}], \'response_time\': 0.77, \'request_id\': \'089824df-a40c-4527-aa98-cbe59b87ea7d\'}', name='tavily_search', id='4118e5d7-d1fa-4 ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='d40f2c7e-fd94-4e58-b716-4fd87a85a260'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1322, 'total_tokens': 1347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXr7sElDKX29E6bliPoiqNDEEok8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-5631-7560-93e0-6dfa60d11f3c-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'search_depth': 'fast'}, 'id': 'call_0XfxTPbYgaAf5p8aOI8jhPeq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 25, 'total_tokens': 1347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.instagram.com/popular/current-weather-los-angeles-april-2026\', \'title\': \'Current Weather Los Angeles April 2026\', \'content\': \'Log In\\n\\nSign Up\\n\\n# Current Weather Los Angeles April 2026\\n\\nWatch reels about current weather los angeles april 2026 from people around the world.\\n\\nYour 21 March 2026 weather update for Los Angeles\\n\\n☀️ Los Angeles, United States — Sunny 21 March 2026 (27°C). Wind 9 km/h • UV 7 • Rain 0 mm. Save for later ✅\\n\\n#Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Sunny, #Sun, #Rain, #Cloudy, #Storm\\n\\n122 [...] 93\\n\\nYour 7 March 2026 weather update for Los Angeles ☀️ Forecast for 7 March 2026 in Los Angeles: Sunny. Temp 23°C, wind 7 km/h. Comment your district 🗺️ #Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Sunny, #Sun, #Rain, #Cloudy, #Storm\\n\\nWeather in Los Angeles 3 April 2026: Overcast (24°C)\\n\\n☁️ Quick forecast in Los Angeles: Overcast, 24°C. UV 7 • Rain 0 mm. Share in story if useful 📲 [...] 122\\n\\nYour 21 March 2026 weather update for Los Angeles ☀️ Los Angeles, United States — Sunny 21 March 2026 (27°C). Wind 9 km/h • UV 7 • Rain 0 mm. Save for later ✅ #Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Sunny, #Sun, #Rain, #Cloudy, #Storm\\n\\nYour 24 March 2026 weather update for Los Angeles\\n\\n☀️ Forecast for 24 March 2026 in Los Angeles: Sunny. Temp 25°C, wind 10 km/h. Comment your district 🗺️\', \'score\': 0.8585411, \'raw_content\': None, \'id\': \'050b03-00\'}, {\'url\': \'https://www.weatherandradar.in/weather/los-angeles/12139441\', \'title\': \'Current weather for Los Angeles\', \'content\': "Weather Los Angeles\\n\\nWeather News\\n\\nEditor\'s Pick\\n\\nDiscover the app\\n\\nWeather widget\\n\\nContact us\\n\\nCalifornia · United States  Wed, 29/07 06:11 am PDT\\n\\n# Weather Los Angeles\\n\\n now \\n90 Min. Weather\\n\\nmostly cloudy\\n\\nSunrise and sunset 06:02 am  07:56 pm\\n\\n07:00 am\\n\\n21\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n08:00 am\\n\\n21\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\n09:00 am\\n\\n22\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\n10:00 am\\n\\n24\\n\\n°\\n\\nProbability of precipitation\\n\\n5 %\\n\\n11:00 am\\n\\n25\\n\\n° [...] 5 %\\n\\nToday, in the morning it is partly cloudy. Towards the afternoon, the sun comes out. The temperature is currently at 21 degrees and rises to 29 degrees during the day.\\n\\n## WeatherRadar\\n\\n## Forecast Map\\n\\nMorning\\n\\n22\\n\\n°\\n\\nProbability of precipitation\\n\\n10 %\\n\\nAfternoon\\n\\n29\\n\\n°\\n\\nProbability of precipitation\\ ...
# {'messages': [AIMessage(content='The current weather in Los Angeles is mostly cloudy with a temperature of 21 degrees. The temperature is expected to rise to 29 degrees during the day.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 2608, 'total_tokens': 2640, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrCIm7MY96yt7g5TFDZ8w1oBwka', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-6a2f-7fa3-80e7-0407756b27ff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2608, 'output_tokens': 32, 'total_tokens': 2640, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:17.593245+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe3-6996-8000-9cb037728ede'}}, tasks=(PregelTask(id='055ed5e4-6c76-b946-e317-10ec3ccdcf1d', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search',
#   'args': {'query': 'current weather in Los Angeles'},
#   'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a',
#   'type': 'tool_call'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'configurable': {'thread_id': '3',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1930d7-1af6-6e78-8002-ef7e54a373a5'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1af6-6e78-8002-ef7e54a373a5'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-08-08T09:42:17.637635+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, tasks=(PregelTask(id='face5ed7-305d-c52b-d367-c0e5ce1b5d8a', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.aqi.in/weather/us/united-states/louisiana/baton-rouge\', \'title\': \'Baton Rouge Weather Conditions: Temperature | 30 Days Forecast\', \'content\': "August 2026 in Baton Rouge is forecast to have 13 sunny days, 18 rainy days, 0 cloudy days, and 0 snowy days. Temperatures for the month range from lows around 22°C to highs of 39°C.\\n\\n6. How does the weather in Baton Rouge affect air quality? [...] ConditionSunny\\n\\nHumidity77 %\\n\\nFeels36 °C\\n\\nCover0 %\\n\\nVisibility10 km\\n\\nWind Speed & Dir.9.7 kmph /  ESE\\n\\nUV1.7\\n\\n## Baton Rouge 30-Days (August 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny39°25°\\n\\n2\\n\\nSunny34°25°\\n\\n3\\n\\nSunny37°22°\\n\\n4\\n\\nSunny35°23°\\n\\n5\\n\\nSunny37°24°\\n\\n6Today\\n\\nSunny34°25°\\n\\n7\\n\\nSunny36°24°\\n\\n8\\n\\nSunny36°24°\\n\\n9\\n\\nSunny37°23°\\n\\n10\\n\\nSunny37°24°\\n\\n11\\n\\nSunny36°25°\\n\\n12\\n\\nSunny34°25°\\n\\n13\\n\\nSunny38°25°\\n\\n14\\n\\nRain Showers33°24°\\n\\n15\\n\\nRain Showers34°24°\\n\\n16\\n\\nRain Showers34°24°\\n\\n17 [...] From 05:00 PM 06 August 2026, Baton Rouge\'s 10-day forecast shows this trend: Today (Aug. 6) : Temp. 27°C, Hum. 85% and Sunny condition. Friday (Aug. 7) : Temp. 28°C, Hum. 70% and Sunny condition. Saturday (Aug. 8) : Temp. 29°C, Hum. 70% and Sunny condition. Sunday (Aug. 9) : Temp. 29°C, Hum. 68% and Sunny condition. Monday (Aug. 10) : Temp. 30°C, Hum. 66% and Sunny condition. Tuesday (Aug. 11) : Temp. 30°C, Hum. 68% and Sunny condition. Wednesday (Aug. 12) : Temp. 29°C, Hum. 71% and Sunny", \'score\': 0.85008353, \'raw_content\': None, \'id\': \'5ea1df-00\'}, {\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1786182072, \'localtime\': \'2026-08-08 04:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 04:30\', \'temp_c\': 21.8, \'temp_f\': 71.2, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 10.5, \'wind_kph\': 16.9, \'wind_degree\': 254, \'wind_dir\': \'WSW\', \'pressure_mb\': 1015.0, \'pressure_in\': 29.97, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 83, \'cloud\': 1, \'feelslike_c\': 21.7, \'feelslike_f\': 71.1, \'windchill_c\': 21.8, \'windchill_f\': 71.2, \'heatindex_c\': 24.4, \'heatindex_f\': 76.0, \'dewpoint_c\': 18.8, \'dewpoint_f\': 65.8, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 0.0, \'gust_mph\': 21.0, \'gust_kph\': 33.8, \'will_it_rain\': 0, \'chance_of_rain\': 10, \'will_it_snow\': 0, \'chance_of_snow\': 0, \'wetbulb_c\': 19.7, \'wetbulb_f\': 67.5}}", \'score\': 0.838098, \'raw_content\': None, \'id\': \'9b28c9-01\'}], \'response_time\': 0.0, \'request_id\': \'af89c46d-0491-4256-89b7-748dea8219ad\'}', name='tavily_search', id='91375854-b47e-40e0-99d0-34715de6c0a3', tool_call_id='call_r0FdeJui0SO8J7Wzw3bggc5a')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.aqi.in/weather/us/united-states/louisiana/baton-rouge\', \'title\': \'Baton Rouge Weather Conditions: Temperature | 30 Days Forecast\', \'content\': "August 2026 in Baton Rouge is forecast to have 13 sunny days, 18 rainy days, 0 cloudy days, and 0 snowy days. Temperatures for the month range from lows around 22°C to highs of 39°C.\\n\\n6. How does the weather in Baton Rouge affect air quality? [...] ConditionSunny\\n\\nHumidity77 %\\n\\nFeels36 °C\\n\\nCover0 %\\n\\nVisibility10 km\\n\\nWind Speed & Dir.9.7 kmph /  ESE\\n\\nUV1.7\\n\\n## Baton Rouge 30-Days (August 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny39°25°\\n\\n2\\n\\nSunny34°25°\\n\\n3\\n\\nSunny37°22°\\n\\n4\\n\\nSunny35°23°\\n\\n5\\n\\nSunny37°24°\\n\\n6Today\\n\\nSunny34°25°\\n\\n7\\n\\nSunny36°24°\\n\\n8\\n\\nSunny36°24°\\n\\n9\\n\\nSunny37°23°\\n\\n10\\n\\nSunny37°24°\\n\\n11\\n\\nSunny36°25°\\n\\n12\\n\\nSunny34°25°\\n\\n13\\n\\nSunny38°25°\\n\\n14\\n\\nRain Showers33°24°\\n\\n15\\n\\nRain Showers34°24°\\n\\n16\\n\\nRain Showers34°24°\\n\\n17 [...] From 05:00 PM 06 August 2026, Baton Rouge\'s 10-day forecast shows this trend: Today (Aug. 6) : Temp. 27°C, Hum. 85% and Sunny condition. Friday (Aug. 7) : Temp. 28°C, Hum. 70% and Sunny condition. Saturday (Aug. 8) : Temp. 29°C, Hum. 70% and Sunny condition. Sunday (Aug. 9) : Temp. 29°C, Hum. 68% and Sunny condition. Monday (Aug. 10) : Temp. 30°C, Hum. 66% and Sunny condition. Tuesday (Aug. 11) : Temp. 30°C, Hum. 68% and Sunny condition. Wednesday (Aug. 12) : Temp. 29°C, Hum. 71% and Sunny", \'score\': 0.85008353, \'raw_content\': None, \'id\': \'5ea1df-00\'}, {\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1786182072, \'localtime\': \'2026-08-08 04:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 04:30\', \'temp_c\': 21.8, \'temp_f\': 71.2, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 10.5, \'wind_kph\': 16.9, \'wind_degree\': 254, \'wind_dir\': \'WSW\', \'pressure_mb\': 1015.0, \'pressure_in\': 29.97, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 83, \'cloud\': 1, \'feelslike_c\': 21.7, \'feelslike_f\': 71.1, \'windchill_c\': 21.8, \'windchill_f\': 71.2, \'heatindex_c\': 24.4, \'heatindex_f\': 76.0, \'dewpoint_c\': 18.8, \'dewpoint_f\': 65.8, \'vis_km\': ...
# {'messages': [AIMessage(content='The current weather in Louisiana is clear, with a temperature of 71.2°F. The humidity is at 83%, and the wind speed is 16.9 km/h coming from the WSW direction. The chance of rain is 10%.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 2529, 'total_tokens': 2581, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrGNs8qfGb9LOIsk33pXwhlhMiX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-791e-7ed0-86fd-e28b3b6e7832-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2529, 'output_tokens': 52, 'total_tokens': 2581, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.aqi.in/weather/us/united-states/louisiana/baton-rouge\', \'title\': \'Baton Rouge Weather Conditions: Temperature | 30 Days Forecast\', \'content\': "August 2026 in Baton Rouge is forecast to have 13 sunny days, 18 rainy days, 0 cloudy days, and 0 snowy days. Temperatures for the month range from lows around 22°C to highs of 39°C.\\n\\n6. How does the weather in Baton Rouge affect air quality? [...] ConditionSunny\\n\\nHumidity77 %\\n\\nFeels36 °C\\n\\nCover0 %\\n\\nVisibility10 km\\n\\nWind Speed & Dir.9.7 kmph /  ESE\\n\\nUV1.7\\n\\n## Baton Rouge 30-Days (August 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny39°25°\\n\\n2\\n\\nSunny34°25°\\n\\n3\\n\\nSunny37°22°\\n\\n4\\n\\nSunny35°23°\\n\\n5\\n\\nSunny37°24°\\n\\n6Today\\n\\nSunny34°25°\\n\\n7\\n\\nSunny36°24°\\n\\n8\\n\\nSunny36°24°\\n\\n9\\n\\nSunny37°23°\\n\\n10\\n\\nSunny37°24°\\n\\n11\\n\\nSunny36°25°\\n\\n12\\n\\nSunny34°25°\\n\\n13\\n\\nSunny38°25°\\n\\n14\\n\\nRain Showers33°24°\\n\\n15\\n\\nRain Showers34°24°\\n\\n16\\n\\nRain Showers34°24°\\n\\n17 [...] From 05:00 PM 06 August 2026, Baton Rouge\'s 10-day forecast shows this trend: Today (Aug. 6) : Temp. 27°C, Hum. 85% and Sunny condition. Friday (Aug. 7) : Temp. 28°C, Hum. 70% and Sunny condition. Saturday (Aug. 8) : Temp. 29°C, Hum. 70% and Sunny condition. Sunday (Aug. 9) : Temp. 29°C, Hum. 68% and Sunny condition. Monday (Aug. 10) : Temp. 30°C, Hum. 66% and Sunny condition. Tuesday (Aug. 11) : Temp. 30°C, Hum. 68% and Sunny condition. Wednesday (Aug. 12) : Temp. 29°C, Hum. 71% and Sunny", \'score\': 0.85008353, \'raw_content\': None, \'id\': \'5ea1df-00\'}, {\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1786182072, \'localtime\': \'2026-08-08 04:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 04:30\', \'temp_c\': 21.8, \'temp_f\': 71.2, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 10.5, \'wind_kph\': 16.9, \'wind_degree\': 254, \'wind_dir\': \'WSW\', \'pressure_mb\': 1015.0, \'pressure_in\': 29.97, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 83, \'cloud\': 1, \'feelslike_c\': 21.7, \'feelslike_f\': 71.1, \'windchill_c\': 21.8, \'windchill_f\': 71.2, \'heatindex_c\': 24.4, \'heatindex_f\': 76.0, \'dewpoint_c\': 18.8, \'dewpoint_f ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.aqi.in/weather/us/united-states/louisiana/baton-rouge\', \'title\': \'Baton Rouge Weather Conditions: Temperature | 30 Days Forecast\', \'content\': "August 2026 in Baton Rouge is forecast to have 13 sunny days, 18 rainy days, 0 cloudy days, and 0 snowy days. Temperatures for the month range from lows around 22°C to highs of 39°C.\\n\\n6. How does the weather in Baton Rouge affect air quality? [...] ConditionSunny\\n\\nHumidity77 %\\n\\nFeels36 °C\\n\\nCover0 %\\n\\nVisibility10 km\\n\\nWind Speed & Dir.9.7 kmph /  ESE\\n\\nUV1.7\\n\\n## Baton Rouge 30-Days (August 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny39°25°\\n\\n2\\n\\nSunny34°25°\\n\\n3\\n\\nSunny37°22°\\n\\n4\\n\\nSunny35°23°\\n\\n5\\n\\nSunny37°24°\\n\\n6Today\\n\\nSunny34°25°\\n\\n7\\n\\nSunny36°24°\\n\\n8\\n\\nSunny36°24°\\n\\n9\\n\\nSunny37°23°\\n\\n10\\n\\nSunny37°24°\\n\\n11\\n\\nSunny36°25°\\n\\n12\\n\\nSunny34°25°\\n\\n13\\n\\nSunny38°25°\\n\\n14\\n\\nRain Showers33°24°\\n\\n15\\n\\nRain Showers34°24°\\n\\n16\\n\\nRain Showers34°24°\\n\\n17 [...] From 05:00 PM 06 August 2026, Baton Rouge\'s 10-day forecast shows this trend: Today (Aug. 6) : Temp. 27°C, Hum. 85% and Sunny condition. Friday (Aug. 7) : Temp. 28°C, Hum. 70% and Sunny condition. Saturday (Aug. 8) : Temp. 29°C, Hum. 70% and Sunny condition. Sunday (Aug. 9) : Temp. 29°C, Hum. 68% and Sunny condition. Monday (Aug. 10) : Temp. 30°C, Hum. 66% and Sunny condition. Tuesday (Aug. 11) : Temp. 30°C, Hum. 68% and Sunny condition. Wednesday (Aug. 12) : Temp. 29°C, Hum. 71% and Sunny", \'score\': 0.85008353, \'raw_content\': None, \'id\': \'5ea1df-00\'}, {\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1786182072, \'localtime\': \'2026-08-08 04:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 04:30\', \'temp_c\': 21.8, \'temp_f\': 71.2, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 10.5, \'wind_kph\': 16.9, \'wind_degree\': 254, \'wind_dir\': \'WSW\', \'pressure_mb\': 1015.0, \'pressure_in\': 29.97, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 83, \'cloud\': 1, \'feelslike_c\': 21.7, \'feelslike_f\': 71.1, \'windchill_c\': 21.8, \'windchill_f\': 71.2, \'heatindex_c\': 24.4, \'heatindex_f\': 76.0, \'dewpoint_c\': 18.8, \'dewpoint_f ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1af6-6e78-8002-ef7e54a373a5'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-08-08T09:42:17.637635+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, tasks=(PregelTask(id='face5ed7-305d-c52b-d367-c0e5ce1b5d8a', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.aqi.in/weather/us/united-states/louisiana/baton-rouge\', \'title\': \'Baton Rouge Weather Conditions: Temperature | 30 Days Forecast\', \'content\': "August 2026 in Baton Rouge is forecast to have 13 sunny days, 18 rainy days, 0 cloudy days, and 0 snowy days. Temperatures for the month range from lows around 22°C to highs of 39°C.\\n\\n6. How does the weather in Baton Rouge affect air quality? [...] ConditionSunny\\n\\nHumidity77 %\\n\\nFeels36 °C\\n\\nCover0 %\\n\\nVisibility10 km\\n\\nWind Speed & Dir.9.7 kmph /  ESE\\n\\nUV1.7\\n\\n## Baton Rouge 30-Days (August 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny39°25°\\n\\n2\\n\\nSunny34°25°\\n\\n3\\n\\nSunny37°22°\\n\\n4\\n\\nSunny35°23°\\n\\n5\\n\\nSunny37°24°\\n\\n6Today\\n\\nSunny34°25°\\n\\n7\\n\\nSunny36°24°\\n\\n8\\n\\nSunny36°24°\\n\\n9\\n\\nSunny37°23°\\n\\n10\\n\\nSunny37°24°\\n\\n11\\n\\nSunny36°25°\\n\\n12\\n\\nSunny34°25°\\n\\n13\\n\\nSunny38°25°\\n\\n14\\n\\nRain Showers33°24°\\n\\n15\\n\\nRain Showers34°24°\\n\\n16\\n\\nRain Showers34°24°\\n\\n17 [...] From 05:00 PM 06 August 2026, Baton Rouge\'s 10-day forecast shows this trend: Today (Aug. 6) : Temp. 27°C, Hum. 85% and Sunny condition. Friday (Aug. 7) : Temp. 28°C, Hum. 70% and Sunny condition. Saturday (Aug. 8) : Temp. 29°C, Hum. 70% and Sunny condition. Sunday (Aug. 9) : Temp. 29°C, Hum. 68% and Sunny condition. Monday (Aug. 10) : Temp. 30°C, Hum. 66% and Sunny condition. Tuesday (Aug. 11) : Temp. 30°C, Hum. 68% and Sunny condition. Wednesday (Aug. 12) : Temp. 29°C, Hum. 71% and Sunny", \'score\': 0.85008353, \'raw_content\': None, \'id\': \'5ea1df-00\'}, {\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1786182072, \'localtime\': \'2026-08-08 04:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 04:30\',  ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:17.593245+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe3-6996-8000-9cb037728ede'}}, tasks=(PregelTask(id='055ed5e4-6c76-b946-e317-10ec3ccdcf1d', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe3-6996-8000-9cb037728ede'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-08T09:42:16.476288+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe0-6ea8-bfff-167c5971ad75'}}, tasks=(PregelTask(id='6a70ba8b-176c-082f-34da-cfdbd28450b8', name='llm', path=('__pregel_pull', 'llm'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=())
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe0-6ea8-bfff-167c5971ad75'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-08T09:42:16.475196+00:00', parent_config=None, tasks=(PregelTask(id='bab19286-f996-020e-59c6-8861ac45e352', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={})]}),), interrupts=())
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:17.593245+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe3-6996-8000-9cb037728ede'}}, tasks=(PregelTask(id='055ed5e4-6c76-b946-e317-10ec3ccdcf1d', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1786182066, \'localtime\': \'2026-08-08 02:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 02:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 2.9, \'wind_kph\': 4.7, \'wind_degree\': 212, \'wind_dir\': \'SSW\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 91, \'cloud\': 7, \'feelslike_c\': 20.9, \'feelslike_f\': 69.6, \'windchill_c\': 19.1, \'windchill_f\': 66.4, \'heatindex_c\': 19.1, \'heatindex_f\': 66.4, \'dewpoint_c\': 17.7, \'dewpoint_f\': 63.8, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 0.0, \'gust_mph\': 4.1, \'gust_kph\': 6.6, \'will_it_rain\': 0, \'chance_of_rain\': 14, \'will_it_snow\': 0, \'chance_of_snow\': 0, \'wetbulb_c\': 18.1, \'wetbulb_f\': 64.7}}", \'score\': 0.7635197, \'raw_content\': None, \'id\': \'9c3d80-00\'}, {\'url\': \'https://www.trustpilot.com/review/current.com\', \'title\': \'Read Customer Service Reviews of current.com\', \'content\': "Verified\\n\\n## I absolutely love my Current account\\nI absolutely love my Current account. App use is intuitive. The options for rollover savings from purchases, as well as multiple cards to be used in the physical form as well as digital, is beyond convenient. The optional overdraft has saved me more than I can tell you. I don\'t want to ever leave Current. The only thing that would make them better is if they had live customer service.\\n\\nJuly 29, 2026\\n\\nUseful\\n\\nShare\\n\\nLA\\n\\nLakendra US•1 review [...] Verified\\n\\n## Current is OUTSTANDING!!!\\nCurrent has always been there when I’m in a jam. From being short 20 bucks to fill my gas tank up or 500 to cover an unexpected bill. Current has also never let me down when it comes to ACH transactions and depositing my money the second it clears the senders account. I’m very satisfied with my current banking situation and very happy I made the switch!\\n\\nJuly 30, 2026\\n\\nUseful\\n\\nShare\\n\\nSee 1 more review by Zachary\\n\\nNO\\n\\nNoland US•1 review\\n\\n9 hours ago [...] Verified\\n\\n## Got paid 2 days early\\nGot paid 2 days early, something that never happened the 6 years I banked with Chime!\\n\\nJuly 30, 2026\\n\\nUseful\\n\\nShare\\n\\nDE\\n\\nDeanna US•1 review\\n\\n4 hours ago\\n\\nImage 35: Rated 5 out of 5 stars\\n\\nVerified", \'score\': 0.09726189, \'raw_content\': None, \'id\': \'e8bdb7-01\'}], \'response_time\': 0.0, \'request_id\': \'f8ac295f-3ec8-4147-9f1c-f5647d109221\'}', name='tavily_search', id='c1c78116-183e-416e-9340-07cf61f3ea55', tool_call_id='call_r0FdeJui0SO8J7Wzw3bggc5a')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1786182066, \'localtime\': \'2026-08-08 02:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 02:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 2.9, \'wind_kph\': 4.7, \'wind_degree\': 212, \'wind_dir\': \'SSW\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 91, \'cloud\': 7, \'feelslike_c\': 20.9, \'feelslike_f\': 69.6, \'windchill_c\': 19.1, \'windchill_f\': 66.4, \'heatindex_c\': 19.1, \'heatindex_f\': 66.4, \'dewpoint_c\': 17.7, \'dewpoint_f\': 63.8, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 0.0, \'gust_mph\': 4.1, \'gust_kph\': 6.6, \'will_it_rain\': 0, \'chance_of_rain\': 14, \'will_it_snow\': 0, \'chance_of_snow\': 0, \'wetbulb_c\': 18.1, \'wetbulb_f\': 64.7}}", \'score\': 0.7635197, \'raw_content\': None, \'id\': \'9c3d80-00\'}, {\'url\': \'https://www.trustpilot.com/review/current.com\', \'title\': \'Read Customer Service Reviews of current.com\', \'content\': "Verified\\n\\n## I absolutely love my Current account\\nI absolutely love my Current account. App use is intuitive. The options for rollover savings from purchases, as well as multiple cards to be used in the physical form as well as digital, is beyond convenient. The optional overdraft has saved me more than I can tell you. I don\'t want to ever leave Current. The only thing that would make them better is if they had live customer service.\\n\\nJuly 29, 2026\\n\\nUseful\\n\\nShare\\n\\nLA\\n\\nLakendra US•1 review [...] Verified\\n\\n## Current is OUTSTANDING!!!\\nCurrent has always been there when I’m in a jam. From being short 20 bucks to fill my gas tank up or 500 to cover an unexpected bill. Current has also never let me down when it comes to ACH transactions and depositing my money the second it clears the senders account. I’m very satisfied with my current banking situation and very happy I made the switch!\\n\\nJuly 30, 2026\\n\\nUseful\\n\\nShare\\n\\nSee 1 more review by Zachary\\n\\nNO\\n\\nNoland US•1 review\\n\\n9 hours ago [...] Verified\\n\\n## Got paid 2 days early\\nGot paid 2 days early, something that never happened the 6 years I banked with Chime!\\n\\nJuly 30, 2026\\n\\nUseful\\n\\nShare\\n\\nDE\\n ...
# {'messages': [AIMessage(content='The current weather in Los Angeles is clear with a temperature of 66.4°F (19.1°C). The wind speed is 4.7 km/h coming from the SSW direction. The humidity is at 91%, and there is a 14% chance of rain.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 2325, 'total_tokens': 2384, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrIehUi3S6FJNg27bI2ow1Vphsu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-81e6-7470-8d9d-c0150c3970ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2325, 'output_tokens': 59, 'total_tokens': 2384, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:17.593245+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe3-6996-8000-9cb037728ede'}}, tasks=(PregelTask(id='055ed5e4-6c76-b946-e317-10ec3ccdcf1d', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in LA, accuweather\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/10-day-weather-forecast/347625\', \'title\': \'Los Angeles, CA 10-Day Weather | AccuWeather\', \'content\': \'WindSW 9 km/h\\n\\n## Sat 8/8\\n\\nHeat Advisory\\n\\n10:00 AM Saturday - 8:00 PM Sunday\\n\\nRealFeel®35°\\n\\nRealFeel Shade™30°\\n\\nMax UV Index11.0 (Extreme)\\n\\nWindSW 13 km/h\\n\\n## Sun 8/9\\n\\nHeat Advisory\\n\\n10:00 AM Saturday - 8:00 PM Sunday\\n\\nRealFeel®35°\\n\\nRealFeel Shade™30°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSSW 13 km/h\\n\\n## Mon 8/10\\n\\nRealFeel®38°\\n\\nRealFeel Shade™31°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Tue 8/11\\n\\nRealFeel®36°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Wed 8/12 [...] ## Wed 8/12\\n\\nRealFeel®36°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Thu 8/13\\n\\nRealFeel®35°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Fri 8/14\\n\\nRealFeel®32°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSW 7 km/h\\n\\n## Sat 8/15\\n\\nRealFeel®34°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 7 km/h\\n\\n## Sun 8/16\\n\\nRealFeel®34°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSSW 6 km/h\\n\\n## Mon 8/17\\n\\nRealFeel®31° [...] RealFeel®31°\\n\\nRealFeel Shade™27°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 11 km/h\\n\\n## Tue 8/18\\n\\nRealFeel®32°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 9 km/h\\n\\n## Wed 8/19\\n\\nRealFeel®32°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 9 km/h\\n\\n## Thu 8/20\\n\\nRealFeel®35°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindWNW 4 km/h\\n\\n## Fri 8/21\\n\\nRealFeel®35°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindWSW 2 km/h\\n\\n## Around the Globe\\n\\nAround the Globe\', \'score\': 0.7711725, \'raw_content\': None, \'id\': \'7d6cf7-00\'}, {\'title\': \'Weather in Los Angeles, CA\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1786182078, \'localtime\': \'2026-08-08 02:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 02:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 2.9, \'wind_kph\': 4.7, \'wind_degree\': 212, \'wind_dir\': \'SSW\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 91, \'cloud\': 7, \'feelslike_c\': 20.9, \'feelslike_f\': 69.6, \'windchill_c\': 19.1, \'windchill_f\': 66.4, \'heatindex_c\': 19.1, \'heatindex_f\': 66.4, \'dewpoint_c\': 17.7, \'dewpoint_f\': 63.8, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 0.0, \'gust_mph\': 4.1, \'gust_kph\': 6.6, \'will_it_rain\': 0, \'chance_of_rain\': 14, \'will_it_snow\': 0, \'chance_of_snow\': 0, \'wetbulb_c\': 18.1, \'wetbulb_f\': 64.7}}", \'score\': 0.7476885, \'raw_content\': None, \'id\': \'e57aa9-01\'}], \'response_time\': 0.0, \'request_id\': \'30e422a1-e285-40a6-afe4-16621afaa404\'}', name='tavily_search', id='bfd299de-a507-4562-a297-e5c6cba92a3d', tool_call_id='call_r0FdeJui0SO8J7Wzw3bggc5a')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in LA, accuweather\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/10-day-weather-forecast/347625\', \'title\': \'Los Angeles, CA 10-Day Weather | AccuWeather\', \'content\': \'WindSW 9 km/h\\n\\n## Sat 8/8\\n\\nHeat Advisory\\n\\n10:00 AM Saturday - 8:00 PM Sunday\\n\\nRealFeel®35°\\n\\nRealFeel Shade™30°\\n\\nMax UV Index11.0 (Extreme)\\n\\nWindSW 13 km/h\\n\\n## Sun 8/9\\n\\nHeat Advisory\\n\\n10:00 AM Saturday - 8:00 PM Sunday\\n\\nRealFeel®35°\\n\\nRealFeel Shade™30°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSSW 13 km/h\\n\\n## Mon 8/10\\n\\nRealFeel®38°\\n\\nRealFeel Shade™31°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Tue 8/11\\n\\nRealFeel®36°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Wed 8/12 [...] ## Wed 8/12\\n\\nRealFeel®36°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Thu 8/13\\n\\nRealFeel®35°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSSW 4 km/h\\n\\n## Fri 8/14\\n\\nRealFeel®32°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindSW 7 km/h\\n\\n## Sat 8/15\\n\\nRealFeel®34°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 7 km/h\\n\\n## Sun 8/16\\n\\nRealFeel®34°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSSW 6 km/h\\n\\n## Mon 8/17\\n\\nRealFeel®31° [...] RealFeel®31°\\n\\nRealFeel Shade™27°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 11 km/h\\n\\n## Tue 8/18\\n\\nRealFeel®32°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 9 km/h\\n\\n## Wed 8/19\\n\\nRealFeel®32°\\n\\nRealFeel Shade™28°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindSW 9 km/h\\n\\n## Thu 8/20\\n\\nRealFeel®35°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index10.0 (Very High)\\n\\nWindWNW 4 km/h\\n\\n## Fri 8/21\\n\\nRealFeel®35°\\n\\nRealFeel Shade™29°\\n\\nMax UV Index9.0 (Very High)\\n\\nWindWSW 2 km/h\\n\\n## Around the Globe\\n\\nAround the Globe\', \'score\': 0.7711725, \'raw_content\': None, \'id\': \'7d6cf7-00\'}, {\'title\': \'Weather in Los Angeles, CA\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1786182078, \'localtime\': \'2026-08-08 02:41\'}, \'current\': {\'last_updated_epoch\': 1786181400, \'last_updated\': \'2026-08-08 02:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_m ...
# {'messages': [AIMessage(content='The current weather in Los Angeles is clear with a temperature of 66.4°F (19.1°C). The wind speed is 4.7 km/h coming from the SSW direction. The humidity is at 91%.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 2717, 'total_tokens': 2765, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrKgIsEN9nfjoO4ctzLNT6kSgVH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-89e7-72d2-9bf9-a0324c463f54-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2717, 'output_tokens': 48, 'total_tokens': 2765, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-1a8a-6926-8001-17d875cfdb33'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:17.593245+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-0fe3-6996-8000-9cb037728ede'}}, tasks=(PregelTask(id='055ed5e4-6c76-b946-e317-10ec3ccdcf1d', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config, 
    state_update, 
    as_node="action")

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c0331492-f90b-4e7d-8a2f-9969f1fce67d'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 1322, 'total_tokens': 1342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrEjnegzgVYTDKpkS2ru3KXKsZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe0c0-729d-7440-bb91-1467324a08d9-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_r0FdeJui0SO8J7Wzw3bggc5a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1322, 'output_tokens': 20, 'total_tokens': 1342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='54 degree celcius', name='tavily_search', id='d9ae6517-8339-4c50-bf30-792608fd8bcb', tool_call_id='call_r0FdeJui0SO8J7Wzw3bggc5a'), AIMessage(content='The current temperature in Los Angeles is 54 degrees Celsius.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1357, 'total_tokens': 1370, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrMxScBqbtxUarta4HMtZ41KIml', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-9060-7f11-8a4d-ecce7cca1d85-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1357, 'output_tokens': 13, 'total_tokens': 1370, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='The current temperature in Los Angeles is 54 degrees Celsius.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1357, 'total_tokens': 1370, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EAXrMxScBqbtxUarta4HMtZ41KIml', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe0c0-9060-7f11-8a4d-ecce7cca1d85-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1357, 'output_tokens': 13, 'total_tokens': 1370, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langgraph.checkpoint.memory import MemorySaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2", 
                              should_continue, 
                              {True: "Node1", False: END})
builder.set_entry_point("Node1")

# %%
memory = MemorySaver()
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69bd-66ba-8004-9bd2986dab0a'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.897843+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}}, tasks=(), interrupts=())

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69bd-66ba-8004-9bd2986dab0a'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.897843+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-08-08T09:42:25.895016+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-619e-8002-44c70924736d'}}, tasks=(PregelTask(id='d2979c8e-9660-bcea-57f1-e0a74861d602', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-619e-8002-44c70924736d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-08T09:42:25.894847+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}, tasks=(PregelTask(id='42c30f26-885d-86c8-1562-4526790fc08f', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:25.894365+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}}, tasks=(PregelTask(id='4c3e24be-8f3d-e035-177f-d95f1be4048d', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-08T09:42:25.893637+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b1-69c8-bfff-97f9f64c940b'}}, tasks=(PregelTask(id='17d206a5-d8c0-7a3b-53ad-7ef34a664489', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b1-69c8-bfff-97f9f64c940b'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-08T09:42:25.893006+00:00', parent_config=None, tasks=(PregelTask(id='2c03db73-c8a9-ec95-5c59-9d53b46b33ae', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69bd-66ba-8004-9bd2986dab0a'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-619e-8002-44c70924736d'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b1-69c8-bfff-97f9f64c940b'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:25.894365+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}}, tasks=(PregelTask(id='4c3e24be-8f3d-e035-177f-d95f1be4048d', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a10-6144-8005-ae593ff6a904'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a0f-615e-8004-0f6316418fa0'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a0d-62fa-8003-e02c5904440c'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a07-6c6a-8002-cffc9d24ab46'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69bd-66ba-8004-9bd2986dab0a'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-619e-8002-44c70924736d'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b1-69c8-bfff-97f9f64c940b'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a10-6144-8005-ae593ff6a904'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-08-08T09:42:25.931702+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a0f-615e-8004-0f6316418fa0'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a0f-615e-8004-0f6316418fa0'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.931294+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a0d-62fa-8003-e02c5904440c'}}, tasks=(PregelTask(id='55ae6f3b-25c7-73b0-7405-2bb52c1baf29', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a0d-62fa-8003-e02c5904440c'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-08-08T09:42:25.930515+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a07-6c6a-8002-cffc9d24ab46'}}, tasks=(PregelTask(id='e4bcbe8a-2006-ab3c-dbe5-7ddf603f1d52', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a07-6c6a-8002-cffc9d24ab46'}}, metadata={'source': 'fork', 'step': 2, 'parents': {}}, created_at='2026-08-08T09:42:25.928298+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}, tasks=(PregelTask(id='1af37c6a-708d-d96a-e1a1-00ce8adf934f', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69bd-66ba-8004-9bd2986dab0a'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.897843+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-682e-8003-e50ebf34adf1'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-08-08T09:42:25.895016+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-619e-8002-44c70924736d'}}, tasks=(PregelTask(id='d2979c8e-9660-bcea-57f1-e0a74861d602', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b6-619e-8002-44c70924736d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-08T09:42:25.894847+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}, tasks=(PregelTask(id='42c30f26-885d-86c8-1562-4526790fc08f', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b4-6ef2-8001-581b866da7e9'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:25.894365+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}}, tasks=(PregelTask(id='4c3e24be-8f3d-e035-177f-d95f1be4048d', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b3-6282-8000-3cc27c9d2914'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-08T09:42:25.893637+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b1-69c8-bfff-97f9f64c940b'}}, tasks=(PregelTask(id='17d206a5-d8c0-7a3b-53ad-7ef34a664489', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-69b1-69c8-bfff-97f9f64c940b'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-08T09:42:25.893006+00:00', parent_config=None, tasks=(PregelTask(id='2c03db73-c8a9-ec95-5c59-9d53b46b33ae', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
# pip install pygraphviz

# %%
from IPython.display import Image

Image(graph.get_graph().draw_png())

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}} 4
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-6ab2-8003-1a85f91d3d77'}} 3
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-62b0-8002-1a08300ab77c'}} 2
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a30-6fe8-8001-9d7c610d3409'}} 1
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2e-6e0a-8000-5019ff529632'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2d-6a82-bfff-cd72eb88514c'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a30-6fe8-8001-9d7c610d3409'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:25.945182+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2e-6e0a-8000-5019ff529632'}}, tasks=(PregelTask(id='5e55a2d6-bf3e-2042-e09e-0ce5750efe5b', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a30-6fe8-8001-9d7c610d3409'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:25.945182+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2e-6e0a-8000-5019ff529632'}}, tasks=(PregelTask(id='5e55a2d6-bf3e-2042-e09e-0ce5750efe5b', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1930d7-8dbe-67d0-8005-600347e78907'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8dbe-67d0-8005-600347e78907'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-08-08T09:42:29.673147+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}}, tasks=(PregelTask(id='eff06d56-7596-ffb4-8b3d-b5f668a470f7', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.949033+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-6ab2-8003-1a85f91d3d77'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-6ab2-8003-1a85f91d3d77'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-08-08T09:42:25.948736+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-62b0-8002-1a08300ab77c'}}, tasks=(PregelTask(id='4d73db01-1825-7a78-eb42-51df59701a91', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1930d7-8de2-6842-8006-6e05d799efb9'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8de2-6842-8006-6e05d799efb9'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-08-08T09:42:29.687909+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8dbe-67d0-8005-600347e78907'}}, tasks=(PregelTask(id='14daa79d-361e-dc70-7f89-f56464d35143', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8dbe-67d0-8005-600347e78907'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-08-08T09:42:29.673147+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}}, tasks=(PregelTask(id='eff06d56-7596-ffb4-8b3d-b5f668a470f7', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.949033+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-6ab2-8003-1a85f91d3d77'}}, tasks=(), interrupts=())

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e08-62c2-800b-801959ed454b'}}, metadata={'source': 'loop', 'step': 11, 'parents': {}}, created_at='2026-08-08T09:42:29.703334+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e06-63d2-800a-2dd0909fe32f'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e06-63d2-800a-2dd0909fe32f'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2026-08-08T09:42:29.702545+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e05-6bb2-8009-0c0780cca9b9'}}, tasks=(PregelTask(id='05ece7cb-cd07-9ed8-4d42-1ac0c6764671', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e05-6bb2-8009-0c0780cca9b9'}}, metadata={'source': 'loop', 'step': 9, 'parents': {}}, created_at='2026-08-08T09:42:29.702335+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e04-67ee-8008-9a8fef109594'}}, tasks=(PregelTask(id='c3c56ab9-0ac6-988e-df50-3e7c8c6c276a', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e04-67ee-8008-9a8fef109594'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2026-08-08T09:42:29.701828+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e02-6f8e-8007-e1305d023389'}}, tasks=(PregelTask(id='c208615b-4e06-69c3-3fed-6891935a6fc1', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8e02-6f8e-8007-e1305d023389'}}, metadata={'source': 'loop', 'step': 7, 'parents': {}}, created_at='2026-08-08T09:42:29.701204+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8de2-6842-8006-6e05d799efb9'}}, tasks=(PregelTask(id='152d36ed-e165-f938-0952-827b14f2a685', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8de2-6842-8006-6e05d799efb9'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-08-08T09:42:29.687909+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8dbe-67d0-8005-600347e78907'}}, tasks=(PregelTask(id='14daa79d-361e-dc70-7f89-f56464d35143', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-8dbe-67d0-8005-600347e78907'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-08-08T09:42:29.673147+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}}, tasks=(PregelTask(id='eff06d56-7596-ffb4-8b3d-b5f668a470f7', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a3a-6642-8004-1332c7c1786b'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-08T09:42:25.949033+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-6ab2-8003-1a85f91d3d77'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-6ab2-8003-1a85f91d3d77'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-08-08T09:42:25.948736+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-62b0-8002-1a08300ab77c'}}, tasks=(PregelTask(id='4d73db01-1825-7a78-eb42-51df59701a91', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a39-62b0-8002-1a08300ab77c'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-08T09:42:25.948529+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a30-6fe8-8001-9d7c610d3409'}}, tasks=(PregelTask(id='4ea2c7e7-536f-6710-3684-db440fc00d98', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a30-6fe8-8001-9d7c610d3409'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-08T09:42:25.945182+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2e-6e0a-8000-5019ff529632'}}, tasks=(PregelTask(id='5e55a2d6-bf3e-2042-e09e-0ce5750efe5b', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2e-6e0a-8000-5019ff529632'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-08T09:42:25.944317+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2d-6a82-bfff-cd72eb88514c'}}, tasks=(PregelTask(id='ed440936-7e96-d06f-710a-dc14435e6e6a', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1930d7-6a2d-6a82-bfff-cd72eb88514c'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-08T09:42:25.943817+00:00', parent_config=None, tasks=(PregelTask(id='7a40fc51-3b07-ce34-8f57-a393c9b53e62', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# Continue to experiment!
