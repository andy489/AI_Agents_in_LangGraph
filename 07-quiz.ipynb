# %% [markdown]
# # Quiz

# %%
from IPython.display import display, Markdown

questions = [
    {
        "number": 1,
        "text": "Which of the following best describes an agentic workflow in the context of building AI agents?",
        "options": {
            "A": "An agentic workflow is a fixed sequence of tasks where each step is directed by user input and agent autonomy remains limited.",
            "B": "An agentic workflow is an iterative process where agents plan, act, reflect, use tools, and track progress over multiple steps.",
            "C": "An agentic workflow is a cyclical model in which agents break down tasks into parallel subtasks to optimize throughput across distributed systems.",
        },
        "correct": "B",
        "explanation": "This captures the key elements of agentic workflows \u2013 planning, tool use, reflection, and progress tracking, all performed iteratively by agents.",
    },
    {
        "number": 2,
        "text": "In the context of agentic workflows, how do planning, tool use, reflection, multi-agent communication, and memory each contribute to the workflow?",
        "options": {
            "A": "Planning selects participants, tool use manages progress, reflection sets workflow steps, multi-agent communication improves results, and memory coordinates roles.",
            "B": "Planning determines available tools, tool use organizes communication, reflection documents steps, multi-agent communication stores results, and memory enables actions.",
            "C": "Planning sets workflow steps, tool use enables actions, reflection iteratively improves results, multi-agent communication coordinates roles, and memory tracks progress.",
            "D": "Planning iteratively improves results, tool use tracks progress, reflection enables actions, multi-agent communication sets workflow steps, and memory coordinates roles.",
        },
        "correct": "C",
        "explanation": "This option accurately describes the distinct roles of each component in an agentic workflow as presented in the course.",
    },
    {
        "number": 3,
        "text": "Which statement best describes how agentic search differs from standard search methods?",
        "options": {
            "A": "Agentic search aggregates results from multiple search engines without processing or structuring the information, like standard search methods.",
            "B": "Agentic search involves agents decomposing queries, using tools, and extracting structured, relevant data, unlike standard search's simple link retrieval.",
            "C": "Agentic search provides static answers from internal model knowledge, while standard search retrieves dynamic information from external sources.",
            "D": "Agentic search relies on predefined keyword matching and returns a ranked list of links, similar to standard search engines.",
        },
        "correct": "B",
        "explanation": "Agentic search enables agents to break down queries, select the right tools, and return structured information, while standard search typically just provides a list of links.",
    },
    {
        "number": 4,
        "text": "Why are both persistence and streaming important for agents handling long-running tasks?",
        "options": {
            "A": "Persistence lets agents process multiple tasks simultaneously; streaming enables agents to prioritize tasks based on urgency.",
            "B": "Persistence manages agent memory usage over time; streaming helps reduce latency by buffering outputs until completion.",
            "C": "Persistence allows agents to resume long tasks; streaming gives real-time visibility into agent progress during execution.",
            "D": "Persistence allows agents to store temporary variables; streaming is used to batch agent outputs for later review.",
        },
        "correct": "C",
        "explanation": "Persistence is about saving state for resuming tasks, and streaming delivers immediate progress updates, not buffered batches.",
    },
    {
        "number": 5,
        "text": "What is a key advantage of using iterative, cyclical flows instead of single-step generation when building agentic applications?",
        "options": {
            "A": "Iterative, cyclical flows enable stepwise improvement, reflection, and correction\u2014producing higher quality, more controlled agent outputs.",
            "B": "Iterative, cyclical flows streamline the selection and configuration of external tools by automating API discovery and reducing manual integration efforts.",
            "C": "Iterative, cyclical flows allow agents to combine multiple tasks simultaneously, resulting in more rapid but less focused responses overall.",
            "D": "Iterative, cyclical flows enable agents to batch multiple operations into a single request, standardize output formats across steps, and manage concurrent task flows.",
        },
        "correct": "A",
        "explanation": "Iterative, cyclical processes allow agents to refine and improve their work over multiple steps, leading to better and more reliable results.",
    },
    {
        "number": 6,
        "text": "What best describes the ReAct pattern and its role in structuring agent behavior?",
        "options": {
            "A": "The ReAct pattern combines reasoning and acting in a loop \u2013 the agent thinks, acts, observes, and repeats until done.",
            "B": "The ReAct pattern separates reasoning and acting into distinct phases \u2013 the agent plans fully before acting and then stops.",
            "C": "The ReAct pattern emphasizes acting first, then reasoning afterward \u2013 the agent acts, reflects on the action, and finishes the process.",
            "D": "The ReAct pattern merges reasoning and acting into a single step, where the agent generates an action suggestion that implicitly contains its full reasoning process.",
        },
        "correct": "A",
        "explanation": "The ReAct pattern structures agents to alternate between reasoning and acting, enabling complex, iterative problem-solving.",
    },
    {
        "number": 7,
        "text": "In the context of agentic workflow graphs such as those used in LangGraph, how are nodes, edges, and conditional edges defined?",
        "options": {
            "A": "Nodes represent data points; edges store information; conditional edges filter results based on user input in agentic workflow graphs.",
            "B": "Nodes represent agents or functions; edges connect nodes; conditional edges direct flow based on decision logic in agentic workflow graphs.",
            "C": "Nodes store messages or variables; edges transform data; conditional edges automate error handling in agentic workflow graphs.",
            "D": "Nodes execute outputs; edges visualize process steps; conditional edges restrict tool access during agentic workflow execution.",
        },
        "correct": "B",
        "explanation": "Nodes are the active components (agents or functions), edges represent possible transitions, and conditional edges determine which node to visit next depending on runtime decisions.",
    },
]

PASS_THRESHOLD = 5  # out of 7
score = 0

for q in questions:
    display(Markdown(f"---\n### Question {q['number']}\n\n**{q['text']}**"))
    for key, val in q["options"].items():
        display(Markdown(f"- **{key})** {val}"))

    answer = input(f"\nYour answer ({'/'.join(q['options'].keys())}): ").strip().upper()

    if answer == q["correct"]:
        display(Markdown(f"\u2705 **Correct!** {q['explanation']}"))
        score += 1
    else:
        display(Markdown(
            f"\u274c **Incorrect.** The correct answer is **{q['correct']}**: "
            f"{q['options'][q['correct']]}\n\n_{q['explanation']}_"
        ))

pct = score / len(questions) * 100
result = "\u2705 **Passed!**" if score >= PASS_THRESHOLD else "\u274c **Not passed.** Review the lessons and try again."
display(Markdown(
    f"---\n## Final Score: {score}/{len(questions)} ({pct:.0f}%)\n\n"
    f"Pass mark: {PASS_THRESHOLD}/{len(questions)} \u2014 {result}"
))
# Out:
# ---
# ### Question 1
#
# **Which of the following best describes an agentic workflow in the context of building AI agents?**
# - **A)** An agentic workflow is a fixed sequence of tasks where each step is directed by user input and agent autonomy remains limited.
# - **B)** An agentic workflow is an iterative process where agents plan, act, reflect, use tools, and track progress over multiple steps.
# - **C)** An agentic workflow is a cyclical model in which agents break down tasks into parallel subtasks to optimize throughput across distributed systems.
# Your answer (A/B/C):  B
# ✅ **Correct!** This captures the key elements of agentic workflows – planning, tool use, reflection, and progress tracking, all performed iteratively by agents.
# ---
# ### Question 2
#
# **In the context of agentic workflows, how do planning, tool use, reflection, multi-agent communication, and memory each contribute to the workflow?**
# ...
